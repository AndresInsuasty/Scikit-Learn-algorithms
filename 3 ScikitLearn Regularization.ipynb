# %%
import pandas as pd
import sklearn

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/aeiyuni/WHR2017/master/WHROJMP.csv')
dataset.head()
# Out:
#        country  ...  democratic.quality
# 0  Afghanistan  ...           -1.803607
# 1  Afghanistan  ...           -1.792777
# 2  Afghanistan  ...           -1.843384
# 3  Afghanistan  ...           -1.929690
# 4  Afghanistan  ...           -2.044093
#
# [5 rows x 13 columns]

# %%
dataset.describe()
# Out:
#          population  ...  democratic.quality
# count  1.885000e+03  ...         1924.000000
# mean   4.986036e+07  ...           -0.122741
# std    1.645680e+08  ...            0.880628
# min    3.412840e+05  ...           -2.830178
# 25%    4.813608e+06  ...           -0.774016
# 50%    1.142934e+07  ...           -0.212945
# 75%    3.573958e+07  ...            0.635613
# max    1.409517e+09  ...            1.598638
#
# [8 rows x 11 columns]

# %%
x = dataset[['gdp.per.capita.log.scale','social.support','life.expectancy','freedom.of.choice','generosity','perception.of.corruption','confidence.in.national.government','democratic.quality']]
y = dataset[['happiness.index']]

print(x.shape,y.shape)
# Out:
# (1924, 8) (1924, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %% [markdown]
# # Creando Modelos

# %%
modelLinear = LinearRegression().fit(x_train,y_train)
y_predict_linear = modelLinear.predict(x_test)

# %%
modelLasso = Lasso(alpha=0.02).fit(x_train,y_train)
y_predict_lasso = modelLasso.predict(x_test)

# %%
modelRidge = Ridge(alpha=1).fit(x_train, y_train)
y_predict_ridge = modelRidge.predict(x_test)

# %%
modelElastic = ElasticNet(random_state=0).fit(x_train,y_train)
y_predict_Elastic = modelElastic.predict(x_test)

# %% [markdown]
# # Esrimando Perdidas

# %%
linear_loss =mean_squared_error(y_test, y_predict_linear)
print('Linear Loss', linear_loss)
# Out:
# Linear Loss 0.2847855871458237

# %%
lasso_loss = mean_squared_error(y_test,y_predict_lasso)
print('Lasso Loss', lasso_loss)
# Out:
# Lasso Loss 0.340916192291689

# %%
ridge_loss = mean_squared_error(y_test,y_predict_ridge)
print('Ridge Loss', ridge_loss)
# Out:
# Ridge Loss 0.28406908397212777

# %%
elastic_loss = mean_squared_error(y_test,y_predict_Elastic)
print("Elastic Loss", elastic_loss)
# Out:
# Elastic Loss 0.5661970751175631

# %% [markdown]
# # Observando Coeficientes

# %%
print("="*32)
print("Coeficientes Lasso")
print(modelLasso.coef_)

print("="*32)
print("Coeficientes Ridge")
print(modelRidge.coef_)

print("="*32)
print("Coeficientes ElasticNet")
print(modelElastic.coef_)
# Out:
# ...
# Coeficientes Lasso
# [ 0.43545267  0.12063561  0.0303718   0.73996641  0.         -0.
#   0.          0.17013271]
# ...
# Coeficientes Ridge
# [[ 0.32365218  2.04854937  0.02080602  1.36183951  0.3338727  -0.71521956
#   -0.60277592  0.08510277]]
# ...
# Coeficientes ElasticNet
# [ 0.          0.          0.09582766  0.          0.         -0.
#   0.          0.        ]
